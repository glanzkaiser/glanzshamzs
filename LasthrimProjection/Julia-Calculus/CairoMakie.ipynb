# %%
using CairoMakie
CairoMakie.activate!()
Attributes(font = "Open Sans", resolution = (600, 500))

#An example is taken from the site: https://makie.juliaplots.org/stable/basic-tutorials.html

x=range(0,stop=2pi,length=20)
f(x)=sin.(x .^(2))
y=f(x)
lines(x,y,color=:blue)
# Out:
# FigureAxisPlot()

# %%
using CairoMakie

#f(x,y) = cos(x)*cos(y)*sqrt(x^2 + y^2)
f(x,y) = cos(x)*sin(y)

x = range(-10, length = 100, stop = 10)
y = range(-10, length = 100, stop = 10)
z = f.(x, y')
# Out:
# 100×100 Matrix{Float64}:
#  -0.456473   -0.305924   -0.142933   …   0.142933    0.305924    0.456473
#  -0.506573   -0.339501   -0.158621       0.158621    0.339501    0.506573
#  -0.53607    -0.35927    -0.167857       0.167857    0.35927     0.53607
#  -0.543762   -0.364425   -0.170266       0.170266    0.364425    0.543762
#  -0.529338   -0.354758   -0.165749       0.165749    0.354758    0.529338
#  -0.493384   -0.330662   -0.154491   …   0.154491    0.330662    0.493384
#  -0.437362   -0.293117   -0.136949       0.136949    0.293117    0.437362
#  -0.363551   -0.243649   -0.113837       0.113837    0.243649    0.363551
#  -0.274954   -0.184272   -0.0860949      0.0860949   0.184272    0.274954
#  -0.175172   -0.117399   -0.0548509      0.0548509   0.117399    0.175172
#  -0.0682663  -0.0457516  -0.0213759  …   0.0213759   0.0457516   0.0682663
#   0.0414164   0.0277569   0.0129685     -0.0129685  -0.0277569  -0.0414164
#   0.149415    0.100136    0.0467855     -0.0467855  -0.100136   -0.149415
#   ⋮                                  ⋱
#   0.0414164   0.0277569   0.0129685     -0.0129685  -0.0277569  -0.0414164
#  -0.0682663  -0.0457516  -0.0213759      0.0213759   0.0457516   0.0682663
#  -0.175172   -0.117399   -0.0548509  …   0.0548509   0.117399    0.175172
#  -0.274954   -0.184272   -0.0860949      0.0860949   0.184272    0.274954
#  -0.363551   -0.243649   -0.113837       0.113837    0.243649    0.363551
#  -0.437362   -0.293117   -0.136949       0.136949    0.293117    0.437362
#  -0.493384   -0.330662   -0.154491       0.154491    0.330662    0.493384
#  -0.529338   -0.354758   -0.165749   …   0.165749    0.354758    0.529338
#  -0.543762   -0.364425   -0.170266       0.170266    0.364425    0.543762
#  -0.53607    -0.35927    -0.167857       0.167857    0.35927     0.53607
#  -0.506573   -0.339501   -0.158621       0.158621    0.339501    0.506573
#  -0.456473   -0.305924   -0.142933       0.142933    0.305924    0.456473

# %%
surface(x, y, z)
# Out:
# FigureAxisPlot()

# %%
using CairoMakie

fig = Figure()
ax1 = Axis(fig[1, 1])
ax2 = Axis(fig[1, 2])
ax3 = Axis(fig[2, 1:2])
#fig

lines!(ax1, 0..10, sin)
lines!(ax2, 0..10, cos)
lines!(ax3, 0..10, sqrt)
fig
# Out:
# Figure()

# %%
using CairoMakie

fig = Figure()
ax1, l1 = lines(fig[1, 1], 0..10, sin, color = :red)
ax2, l2 = lines(fig[2, 1], 0..10, cos, color = :blue)
Legend(fig[1:2, 2], [l1, l2], ["sin", "cos"])
fig
# Out:
# Figure()
