# %%
using CairoMakie
CairoMakie.activate!()
Attributes(font = "Open Sans", resolution = (600, 500))

#An example is taken from the site: https://makie.juliaplots.org/stable/basic-tutorials.html

x=range(0,stop=2pi,length=40)
f(x)=sin.(x .^23)
y=f(x)
lines(x,y,color=:blue)
# Out:
# FigureAxisPlot()

# %%
using CairoMakie

#f(x,y) = cos(x)*cos(y)*sqrt(x^2 + y^2)
f(x,y) = cos(x)*cos(y^2)

x = range(-10, length = 100, stop = 10)
y = range(-10, length = 100, stop = 10)
z = f.(x, y')
# Out:
# 100×100 Matrix{Float64}:
#  -0.723547    0.151731    0.469989   …   0.469989    0.151731   -0.723547
#  -0.802961    0.168384    0.521573       0.521573    0.168384   -0.802961
#  -0.849715    0.178189    0.551943       0.551943    0.178189   -0.849715
#  -0.861909    0.180746    0.559864       0.559864    0.180746   -0.861909
#  -0.839045    0.175951    0.545012       0.545012    0.175951   -0.839045
#  -0.782055    0.164       0.507994   …   0.507994    0.164      -0.782055
#  -0.693256    0.145379    0.450313       0.450313    0.145379   -0.693256
#  -0.576259    0.120844    0.374316       0.374316    0.120844   -0.576259
#  -0.435824    0.0913942   0.283095       0.283095    0.0913942  -0.435824
#  -0.277663    0.0582271   0.180359       0.180359    0.0582271  -0.277663
#  -0.108208    0.0226916   0.0702877  …   0.0702877   0.0226916  -0.108208
#   0.0656484  -0.0137668  -0.0426428     -0.0426428  -0.0137668   0.0656484
#   0.236835   -0.0496652  -0.153839      -0.153839   -0.0496652   0.236835
#   ⋮                                  ⋱
#   0.0656484  -0.0137668  -0.0426428     -0.0426428  -0.0137668   0.0656484
#  -0.108208    0.0226916   0.0702877      0.0702877   0.0226916  -0.108208
#  -0.277663    0.0582271   0.180359   …   0.180359    0.0582271  -0.277663
#  -0.435824    0.0913942   0.283095       0.283095    0.0913942  -0.435824
#  -0.576259    0.120844    0.374316       0.374316    0.120844   -0.576259
#  -0.693256    0.145379    0.450313       0.450313    0.145379   -0.693256
#  -0.782055    0.164       0.507994       0.507994    0.164      -0.782055
#  -0.839045    0.175951    0.545012   …   0.545012    0.175951   -0.839045
#  -0.861909    0.180746    0.559864       0.559864    0.180746   -0.861909
#  -0.849715    0.178189    0.551943       0.551943    0.178189   -0.849715
#  -0.802961    0.168384    0.521573       0.521573    0.168384   -0.802961
#  -0.723547    0.151731    0.469989       0.469989    0.151731   -0.723547

# %%
surface(x, y, z)
# Out:
# FigureAxisPlot()

# %%
using CairoMakie

fig = Figure()
ax1 = Axis(fig[1, 1])
ax2 = Axis(fig[1, 2])
ax3 = Axis(fig[2, 1:2])
#fig

lines!(ax1, 0..10, sin)
lines!(ax2, 0..10, cos)
lines!(ax3, 0..10, sqrt)
fig
# Out:
# Figure()

# %%
using CairoMakie

fig = Figure()
ax1, l1 = lines(fig[1, 1], 0..10, sin, color = :red)
ax2, l2 = lines(fig[2, 1], 0..10, cos, color = :blue)
Legend(fig[1:2, 2], [l1, l2], ["sin", "cos"])
fig
# Out:
# Figure()
